# %%
import pandas as pd
import yfinance as yf

# %%
import requests

sp500url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
# Add headers to mimic a browser request
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(sp500url, headers=headers)
data_table = pd.read_html(response.text)
# Out:
# /tmp/ipython-input-1115406667.py:7: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_table = pd.read_html(response.text)

# %%
data_table
# Out:
# [    Symbol             Security             GICS Sector  \
#  0      MMM                   3M             Industrials
#  1      AOS          A. O. Smith             Industrials
#  2      ABT  Abbott Laboratories             Health Care
#  3     ABBV               AbbVie             Health Care
#  4      ACN            Accenture  Information Technology
#  ..     ...                  ...                     ...
#  498    XYL           Xylem Inc.             Industrials
#  499    YUM          Yum! Brands  Consumer Discretionary
#  500   ZBRA   Zebra Technologies  Information Technology
#  501    ZBH        Zimmer Biomet             Health Care
#  502    ZTS               Zoetis             Health Care
#
#                                  GICS Sub-Industry    Headquarters Location  \
#  0                        Industrial Conglomerates    Saint Paul, Minnesota
#  1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
data_table[0]
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
tickers = data_table[0]['Symbol'].to_list()

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'ABNB',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'AON',
#  'APA',
#  'APO',
#  'AAPL',
#  'AMAT',
#  'APP',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'XYZ',
#  'BK',
#  'BA',
#  'BKNG',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BLDR',
#  'BG',
#  'BXP',
#  'CHRW',
#  'CDNS',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'COR',
#  'CNC',
#  'CNP',
#  'CF',
#  'CRL',
# ...

# %%
sp500 = yf.download('MSFT', period="max", multi_level_index=False)
# Out:
# /tmp/ipython-input-513098882.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download('MSFT', period="max", multi_level_index=False)
# [*********************100%***********************]  1 of 1 completed

# %%
sp500
# Out:
#                  Close        High         Low        Open      Volume
# Date
# 1986-03-13    0.059500    0.062156    0.054188    0.054188  1031788800
# 1986-03-14    0.061625    0.062688    0.059500    0.059500   308160000
# 1986-03-17    0.062688    0.063219    0.061625    0.061625   133171200
# 1986-03-18    0.061093    0.063219    0.060562    0.062688    67766400
# 1986-03-19    0.060031    0.061625    0.059500    0.061093    47894400
# ...                ...         ...         ...         ...         ...
# 2025-10-16  511.609985  516.849976  508.130005  512.580017    15559600
# 2025-10-17  513.580017  515.479980  507.309998  509.040009    19867800
# 2025-10-20  516.789978  518.700012  513.429993  514.609985    14665600
# 2025-10-21  517.659973  518.690002  513.039978  517.500000    15586200
# 2025-10-22  520.539978  525.219971  517.710022  521.150024    16999848
#
# [9981 rows x 5 columns]

# %%
sp500.index
# Out:
# DatetimeIndex(['1986-03-13', '1986-03-14', '1986-03-17', '1986-03-18',
#                '1986-03-19', '1986-03-20', '1986-03-21', '1986-03-24',
#                '1986-03-25', '1986-03-26',
#                ...
#                '2025-10-09', '2025-10-10', '2025-10-13', '2025-10-14',
#                '2025-10-15', '2025-10-16', '2025-10-17', '2025-10-20',
#                '2025-10-21', '2025-10-22'],
#               dtype='datetime64[ns]', name='Date', length=9981, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#
# 2025-10-16  511.609985  516.849976  508.130005  512.580017  15559600
# 2025-10-17  513.580017  515.479980  507.309998  509.040009  19867800
# 2025-10-20  516.789978  518.700012  513.429993  514.609985  14665600
# 2025-10-21  517.659973  518.690002  513.039978  517.500000  15586200
# 2025-10-22  520.539978  525.219971  517.710022  521.150024  16999848
#
#               Tomorrow  Target
# Date
# 2000-01-03   34.463211       0
# 2000-01-04   34.826569       1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

categories = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[categories], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[categories])

# %%
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.0

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, categories, model):
  model.fit(train[categories], train["Target"])
  preds = model.predict(test[categories])
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
def backtest(data, model, categories, start=2500, step=250):
  all_predictions = []

  for i in range(start, data.shape[0], step):
    train = data.iloc[0:i].copy()
    test = data.iloc[i:(i+step)].copy()
    predictions = predict(train, test, categories, model)
    all_predictions.append(predictions)
  return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, categories)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    2368
# 1    1623
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5200246457178065

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.525432
# 0    0.474568
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_categories = []

for horizon in horizons:
  rolling_averages = sp500.rolling(horizon).mean()

  ratio_column = f"Close_Ratio_{horizon}"
  sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

  trend_column = f"Trend_{horizon}"
  sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

  new_categories += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                  Close        High         Low        Open    Volume  \
# Date
# 2003-12-26   16.799767   16.824464   16.670111   16.700981  12076900
# 2003-12-29   16.954121   16.997340   16.768898   16.799768  40426700
# 2003-12-30   16.991167   17.009689   16.917077   16.923251  34406600
# 2003-12-31   16.898558   17.009691   16.812119   16.929428  42198900
# 2004-01-02   16.947947   17.145518   16.873857   17.028210  44487700
# ...                ...         ...         ...         ...       ...
# 2025-10-15  513.429993  517.190002  510.000000  514.960022  14694700
# 2025-10-16  511.609985  516.849976  508.130005  512.580017  15559600
# 2025-10-17  513.580017  515.479980  507.309998  509.040009  19867800
# 2025-10-20  516.789978  518.700012  513.429993  514.609985  14665600
# 2025-10-21  517.659973  518.690002  513.039978  517.500000  15586200
#
#               Tomorrow  Target  Close_Ratio_2  Trend_2  Close_Ratio_5  \
# Date
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, categories, model):
  model.fit(train[categories], train["Target"])
  preds = model.predict_proba(test[categories])[:,1]
  preds[preds >= .6] = 1
  preds[preds < .6] = 0
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
predictions = backtest(sp500, model, new_categories)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    2767
# 1.0     223
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5605381165919282
